# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" width="45px" src="https://i.ibb.co/cC2YRVh/1434.png" align="left" hspace="10px" vspace="0px"></p>
#
# <h1><strong>Probabilités au Poker</strong></h1>

# %% [markdown]
# ![Background_First_Page.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bienvenue sur ce blog dédié aux mathématiques dans le poker et plus particulièrement aux probabilités dans le poker.
# Dans le cadre du module de modélisations mathématiques, nous avons décidé de nous intéresser à l'application pratique des maths dans la vie de tous les jours.
#
# Nous avons donc formé un groupe de quatre étudiants composé de : BEM Nicolas, BONNE Yannis, BOLLAERT Hugo, JUNG Maxence.
# Le choix de ce sujet nous permet d'étudier la part d'aléatoire et de probabilité poussée avec un arbre de possibilité gigantesque.
#
#
# Notre sujet est donc : les probabilités dans une partie de poker, nous allons donc nous principalement nous intéresser aux probabilités de gagner la phase avec les cartes à notre disposition,
# et ce afin de proposer un algorithme qui nous permettraient d'évaluer les possibilités de victoire.

# %% [markdown]
# # SOMMAIRE
#
# ---
#
#
#
# 1.   Règle du poker
# 2.   Lexique
# 3.   Probbilité simple

# %% [markdown]
# # 1) Règle du poker (Texas hold'em)
#
# ---
#
# Comme son nom l’indique, le texas hold’em a pour origine le Texas.
# C’est une variante du poker, la plus jouée, notamment lors des plus gros tournois de poker, car elle ne possède pas de limite de mise.
#
# Le jeu se joue de 2 à 10 joueurs.
#
# Le but est de créer la meilleure combinaison, qui rapporterait le plus de points et qui permettrait de remporter l’ensemble des jetons misés sur la table.
#
# Chaque début de partie, tous les joueurs reçoivent 2 cartes qu’ils cachent au reste de la table. Dans un second temps, 3 cartes visibles sont déposées au centre de la table.
#
# Progressivement, à chaque tour de table, 1 carte sera ajoutée au centre de la table, jusqu’à atteindre le nombre de 5 au maximum.
# Un tour n’a pas de durée définie, une partie peut se terminer dès le premier tour si les joueurs souhaitent, on appelle cela un “fold”.
#
# Lorsque 3 cartes sont en jeu, on appelle cela un “flop”, avec 4 un “turn” et avec 5 une “river”.
# Si après la “river” plusieurs joueurs sont encore en jeu, on entre dans la phase du “showdown”, c’est la meilleure main qui remporte le pot.
#
# En plus de cela, chaque joueur possède des jetons représentant une certaine somme d’argent. Chaque tour, un joueur peut soit “suivre”, soit “miser” ou soit “se coucher”.
#
# Soit il “suit” et met en jeu la somme d’argent nécessaire pour continuer le jeu, soit il “mise” et mets plus que nécessaire pour forcer les autres joueurs à mettre autant, soit il “se couche” et se retire de la partie en cours. Si le joueur mise tous ses jetons, on appelle cela un “tapis”. Si un joueur ne possède plus de jetons, il perd.

# %% [markdown]
# # 2) Lexique du poker
#
# ---
#
# *Au poker il y a tout un vocabulaire à connaitre avant de commencer à vouloir y jouer en vrai ou en online. Nous allons ici vous expliquer seulement les termes de bases et ceux ue nous allons utiliser au moins une fois dans ce blog mais sachez qu'il en existe bien plus que cela surtout quand on arrive à un niveau professionnel. Beaucoup de terme sont des anglisisme et il existe quasi tout le temps un équivalent français mais comme la plupart des sites, des livres, ou des vidéos utilisent ces anglisisme, nous allons aussi utiliser les termes anglais.*
#
# <h2>Lexique de base au poker</h2>
#
# * Board : Ensemble des cartes communautaires visibles sur la table.
# * Preflop : Commencement de la partie quand tous les joueurs reçoivent leurs cartes.
# * Flop : Arrive juste après le pré-flop. Ensemble des trois premières cartes du board.
# * Turn : Arrive juste arpès le flop. C'est la quatrième carte communautaire.
# * River : Arrive juste arpès la turn. C'est la cinquième et dernière carte communautaire.
# * Showdown : Dévoilement des cartes fermées des joueurs encore en lice après le dernier tour d'enchères.
#
# * Main : Ensemble des cartes qui permette une combinaison à un joueur (dont les siennes)
# * Hauteur : Valeur d'une carte. (exemple roi, ou 9)
# * Couleur : Symbole d'une carte. (exemple carreau, ou coeur)
#
# * Blind : Mise obligatoire versée par deux joueurs avant la distribution des cartes. Les joueurs de blind parlent en dernier lors du premier tour d'enchères. (preflop)
#
# * Pot : Total des enjeux à l'instant t ; autrement dit c'est l'argent au milieu de la table, ce que l'ensemble des joueurs a misé au cours du coup et que le joueur qui a gagné ce coup va empocher.
#
# <h2>Les mains au poker</h2>
#
# * Hauteur : La plus faible des combinaisons de poker. Elle est constituée de... rien. Pas une paire, pas une suite, pas une couleur. On y ajoute généralement le nom de la carte la plus forte de la main.
#
# * Paire : La 2e plus faible des combinaisons de poker. Elle est constitué de deux carte qui ont la même hauteur. (exemple 9♦ et 9♥ forme une paire)
#
# * Double paire : La 3e plus faible des combinaisons de poker. Elle est contitué de 2 paire, 2x deux cartes qui ont la même hauteur. (exemple 9♦ et 9♥ ET 7♠ et 7♦ forme une double paire)
#
# * Brelan : La 4e plus faibles des combinaisons de poker. Il est constitué de trois cartes de même hauteur. (exemple 9♦, 9♥ et 9♠ forme un brelan)
#
# * Straight : La 5e plus faible des combinaisons de poker. Elle est constitué de cinq cartes consécutives formant une suite. (exemple 6♠, 7♦, 8♦, 9♥ et 10♥ forme une straight)
#
# * Flush : La 6e plus faible des combinaisons de poker. Elle est constitué de cinq cartes de même couleur. (exemple 2♥, 7♥, 5♥, Q♥, et A♥ forme une flush)
#
# * Full Housse : La 7e plus faible des combinaisons de poker. Il est constitué d'un brelan et d'une paire. (exemple 2♦, 2♣, 8♦, 8♥, et 8♠ forme un full housse)
#
# * Carré : La 8e plus faibe des combinaisons de poker. Il est constitué de quatre cartes de même hauteur. (exemple 8♥, 8♦, 8♣, et 8♠ forme un carré)
#
# * Straight Flush : La 9e plus faible des combinaisons de poker. Elle est constitué de cinq cartes consécutives de la même couleur. (exemple 2♠, 3♠, 4♠, 5♠, et 6♠ forme une straight flush)
#
# * Straight Flush Royale : La plus forte des combinaisons de poker. Elle est constitué de cinq cartes consécutives de la même couleur, dont la plus haute est un as. (exemple 10♣, J♣, Q♣, K♣, et A♣ forme une straight flush royale)
#
# <h2>Les actions au poker</h2>
#
# * Fold : Abandonner le coup en rendant ses cartes au croupier.
#
# * Check : Action qui consiste à ne pas miser tout en restant dans le coup. Le check est possible lorsque personne n'a misé avant vous au cours de ce tour.
#
# * Bet : Miser une somme pour forcer les autres joueur à au moins mettre autant pour continuer.
#
# * Call : suivre une mise adverse pour continuer le coup.
#
# * Raize : Augmenter le prix à payer pour voir la carte suivante en misant plus que ce qu'un adversaire a misé lors du même tour. Pour relancer, il est nécessaire de miser au moins le double de la mise du joueur.
#
# * Bluff: Mise d'un joueur alors qu'il a une main moins bonne que celle qu'il représente ainsi, et dont le but est de faire coucher l'adversaire.
#
# * All-in : Mise la totalité de ses jetons. SI deux joueurs all-in avant la river, les 2 joueurs dévoilent leur carte et le croupier ajoute les cartes qui manque au board pour arriver à la fin du tour.
#
# <h2>Les positions au poker</h2>
#
# * UTG : l'UTG (Under The Gun) est le premier joueur à parler au preflop, et qui se trouve donc juste après les blinds.
#
# * UTG+1 : Il se trouve gauche du joueur UTG et est donc le 2e joueur à parler au preflop.
#
# * UTG+2 : Il se trouve gauche du joueur UTG+1 et est donc le 3e joueur à parler au preflop. etc... pour UTG+3, UTG+4... (selon le nombre de joueurs à la table)
#
# * Hi-jack : Il se trouve à droite du Cut-Off et à gauche du dernier UTG, le joueur parle après les UTG.
#
# * Cut-off : Il se touve juste à droite du dealer, il parle après le Hi-jack.
#
# * Dealer : Il se trouve à droite de la small blind, il parle après le Cut-off au preflop mais sera le dernier à parler pendant le flop, la turn, et la river.
#
# * Small Blind : Il se trouve à droite de la big blind, il parle en avant dernier au preflop mais le premier à parler pendant le flop, a turn, et la river. C'est la plus petite des deux blinds misées avant la distribution des cartes. Son montant est généralement égal à la moitié de celui de la big blind.
#
# * Big Blind : Il se trouve à droite de l'UGT, il parle en dernier au preflop mais le deuxième à parler pendant le flop, a turn, et la river. C'est la plus grosse des deux blinds misées avant la distribution des cartes. Son montant est généralement égal au double de celui de la small blind.

# %% [markdown]
# # 3) Probabilité simple
#
# ---
#
# *Avant de commencer à voir les probabilité de gagner ou pas selon plusieurs critères leur d'une partie au poker voyant d'abbord quelques probiblités de base. Par exemple la probabilité d'avoir une paire au preflop ou d'avoir une straight au flop, ou un brelan à la turn etc...*
#
# <h3><strong>Preflop</strong></h3>
#
# Commençons avec le commencement d'une partie, le preflop. Quelle la probabilité d'avoir une paire ? D'avoir 2 carte de même couleur ? 2 cartes qui se suivent ?
#
# Avant la distribution des cartes au preflop, toutes les cartes sont encore dans le paquet donc 52. Une fois la première carte distribuée, il n'en reste plsu que 51. La formule pour avoir la probablité d'avoir la/les cartes qui nous intéresse est au final 1 - la probablité de ne pas l'avoir ce qui représente x/51.
#
# > Prenons la probabilité d'avoir une paire. Dans ces 52 cartes il y a en tout 13 paires (paire de 2, de 3, de 4, de 5, de 6, de 7, de 8, de 9, de 10, de Valet, de Dame, de Roi, et d'As). La probabilité d'avoir une paire au preflop est 1 - la probabilité de ne pas avoir une paire. Une fois la première carte distribuée, il reste donc 51 cartes dans le paquet, et il y n'a que 3 cartes qui puissent faire pair avec celle distribuée (si la première carte est le 9♥, il n'y a que le 9♦, le 9♣, et le 9♠ pour avoir une paire). La probabilité de ne pas avoir une paire est donc <strong>48/51 ≈ 0.9412</strong>. Donc la probabilité d'avoir une paire au preflop est <strong>1 - 48/51 ≈ 0.0588</strong> soit 1/17 ou encore environs <strong>5.9%</strong>.
#
# > Pour la probablité d'avoir deux cartes de même couleur on va faire le même procédée. une fois la première carte distribuée, il ne reste que plus 12 cartes de même couleur (si la première carte est le 4♣, il reste toutes les cartes de couleur ♣ : 2♣, 3♣, 5♣, 6♣, 7♣, 8♣, 9♣, 10♣, T♣, D♣, K♣, et A♣). La probablité de ne pas avoir une carte de même couleur est donc <strong>39/51 ≈ 0.74</strong>. Donc la probabilité d'avoir 2 carte de même couleur est donc <strong>1 - 39/51 ≈ 0.2352</strong> soit 4/17 ou encore environs <strong>23.5%</strong>.
#
# > Pour la probablité d'avoir deux cartes qui se suivent toujours pareil. une fois la première carte distribuée, il n'y a que 8 cartes qui suivent celle distribuée (si la première carte est le 4♣, il reste toutes les cartes de hauteur 3 et 5 : 3♣, 3♥, 3♠, 3♦, 4♣, 4♥, 4♦, et 4♣). La probablité de ne pas avoir une carte qui suive la première est donc <strong>43/51 ≈ 0.8431</strong>. Donc la probabilité d'avoir 2 carte qui se suivent au preflop est <strong>1 - 43/51 ≈ 0.1568</strong> soit <strong>8/51</strong> ou encore environs <strong>15.7%</strong>.
#
# <h3><strong>Flop</strong></h3>
#
# Une fois les cartes du preflop distribuée au joueur et reste donc 50 carte dans le paquet et à la fin du flop il en restera 47. A partir de ça nous pouvons calculer quelle est la probabilité d'avoir une main au flop. En effet à partir du flop toutes les mains du poker sont possibles. Pour cela nous allons uiliser une autre tecnhique qui sera plus simple pour nous. Nous allons compter le nombre de chemin posssible qui ammène à la main que nous voulons puis nous diviserons ce nombre par le nombre maximum de maon possible au flop. Ce nombre de chemin maximum est de 50C3 = 19 600 mains possible.
#
# > Commençons avec la paire, quelle est la probabilité d'avoir une et une seule paire au flop avec 2 carte de hauteur différente hauteur au preflop ? Pour cela nous allons calculer le nombre de chemin possible qui ammène à une et une seule paire puis nous diviserons ce nombre par 19 600 pour avoir un pourcentage. Avec la paire on a 6 choix (6 cartes) et comme on ne veut qu'une et une seule paire ont choisi 2 autre cartes totalement différente parmit les 12 autres hauteurs. Cela nous donne <strong>6 * 12C2 * 4C1 * 4C1  = 6 336.</strong> La probabilité est donc <strong>6 336/19 600 ≈ 0.3232</strong> soit environs <strong>32%</strong>.
#
# > Avec la double paire, il faut tiré 1 carte parmis les 3 qui reste pour la première paire puis une autre carte parmi les autres pour la deuxième paire et une autre carte totalement différentes parmi les 44 cartes restante. Cela nous donne <strong>3C1 * 3C1 * 44C1 = 396</strong> la probabilité est donc de <strong>396/19 600 ≈ 0.0202</strong> soit environs <strong>2%</strong>
#
# > Avec le brelan on a 2 possiblité, soit on a déjà une paire est donc on attend juste 1 carte de même hauteur, soit on a 2 cartes différentes et on en a attend 2 de même hauteur qu'une des notre. Commençons avec le faite qu'au preflop on a eu une paire et donc qu'on attende juste une et une seul carte de même hauteur. Il faut tiré 1 carte parmi les 2 cartes qui nous intéresse et 2 autres cartes totalement différentes parmit les 48 restantes. Cela nous donne <strong>2C1 * 48C2 = 2256</strong>. la probabilité est donc de <strong>2256/19 600 ≈ 0.1151</strong> soit environs <strong>11.5%</strong>. Maintenant si au preflop nous avons 2 cartes de hauteurs différentes, quelle est la probabilité d'avoir un brelan avec une des deux cartes ? Pour cela il faut tirer 2 cartes parmis les 3 pour la première carte ou 2 cartes sur les 3 cartes pour la deuxième carte et enfin 1 carte d'hauteur différente parmis celle qui reste. Cela nous donne <strong>(3C2 + 3C2) * 44C1 = 264</strong>. La probabilité est donc de <strong>264/19600 ≈ 0.0135</strong> soit environs <strong>1.3%</strong>.
#
# > Passons maintenant avec la straight, pour avoir une straight il faut obligatoirement avoir deux cartes qui se suivent. Pour cela il faut tirer 3 fois 1 carte parmi les 4 cartes qui composent la hauteur qui nous intéresse. Cela nous donne <strong></strong>
#
# > Pour calculer la probabilité d'avoir un flush il faut de base avoir deux cartes de même couleur. Il ensuite il faut tirer 3 cartes parmis les 11 autres cartes de même couleur. Cela nous donne <strong>11C3 = 165</strong>. La probabilité est donc de <strong>165/19600 ≈ 0.0084</strong> soit environs <strong>0.8%</strong>.
#
# > Avec le full housse nous avons encore deux possibiltés. Soit au preflop nous avons une paire et donc nous attendons 3 cartes de même hauteur au flop. Soit nous avons deux cartes de hauteur différente et dans ce cas nous attendons un carte de même hauteur que la première, et deux autres carte de même hauteur que la deuxième. Si nous avons une paire, il faut tirer 3 cartes de même hauteur parmi les 12 autres hauteurs qu'il nous reste. Cela nous donne <strong>12 * 4C3 = 48</strong>. La probabilité d'avoir un full housse en ayant un paire est donc de <strong>48/19 600 ≈ 0.0024</strong> soit environs <strong>2.4%</strong>. Si maintenant nous avons deux cartes de hauteur différent, il faut tirer une carte de même hauteur que la première et deux carte de même hauteur que la deuxième. Cela nous donne <strong>3C1 * 3C2 = 9</strong>. La probabilité d'avoir un full housse en ayant deux carte de hauteur différentes est donc de <strong>9/19 600 ≈ 0.0005</strong> soit environs <strong>0.05%</strong>.
#
# > Avec le carré il de obligatoirement qu'au preflop nous ayant une paire. Ensuite il fau tirer 2 cartes parmis les 2 qui reste de même hauteur que notre paire et une carte totalement différente parmis celle qui ne nous intéresse pas. Cela nous donne <strong>2C2 * 48C1 = 48</strong>. La probabilité d'avoir un carré est donc de <strong>48/19 600 ≈ 0.0024</strong> soit environs <strong>0.2%</strong>.
#
# <h3><strong>Turn</strong></h3>
#
# Une fois le flop distribué, il reste 47 cartes dans le paquet. À la turn, il n'y qu'une seul carte de tiré ce qui fait 47C1 = 47 mains possibles à la turn.
#
# > Pour la paire, lorsque nous avons donc 2 cartes différentes au preflop et qu'au flop aucune carte nous a donné une paire, ou une meilleure mains que la paire, nous avons 6 cartes qui peuvent nous faire faire une paire. Ce qui nous donne <strong>6/47 ≈ 0.1278</strong> soit <strong>12.8%</strong>.
#
# > Pour la double paire, il faut obligatoirement qu'au preflop le joueur possède 2 cartes de hauteur différente, et que lors du flop le joueur ai déjà une paire. Il faut donc une carte qui face paire avec l'autre carte. Ce qui nous donne <strong>3/47 ≈ 0.0638</strong> soit environs <strong>6.4%</strong>.
#
# > Pour le brelan, il faut soit une paire au preflop, soit 2 cartes différentes au preflop et une carte au flop qui fasse paire avec une de nos cartes. Il faut donc un carte de même hauteur que la paire. Ce qui nous donne <strong>2/47 ≈ 0.0426</strong> soit environs <strong>4.3%</strong>.
#
# > Pour la straight, il faut qu'au preflop, le joueur ai 2 cartes qui se suivent et qu'au flop 2 cartes forment une suite de 4 avec les 2 cartes du joueur. Il faut donc une carte parmi la hauteur qui feraient une suite de 5. Ce qui nous donne <strong>8/47 ≈ 0.1702</strong> soit environs <strong>17%</strong>.
#
# > Pour la flush, il faut qu'au preflop, le joueur ai 2 cartes de même couleur et qu'au flop 2 cartes sont de même couleur que les 2 cartes du joueur. Il faut donc une carte parmi toutes les autres cartes de même couleur. Ce qui nous donne <strong>9/47 ≈ 0.1915</strong> soit environs <strong>19.1%</strong>.
#
# > Pour le full housse, il faut soit qu'au preflop, le joueur ai une paire et qu'au flop il y est une autre paire, soit qu'au preflop le joueur ai 2 cartes de hauteur différentes et qu'au flop il est un  brelan avec une de ses 2 cartes. Dans le premier cas il faut une carte parmi les 2 hauteurs pour formé un brelan. Ce qui nous donne <strong>6/47 ≈ 0.0851</strong> soit environs <strong>8.51%</strong>. Dans le deuxième cas il faut une carte
#
# > Pour le carré, il que soit au preflop, le joueur ai une paire et qu'au flop il y ai 1 carte de même hauteur que la paire, soit qu'au preflop le joueur ai 2 cartes de hauteur différentes et qu'a flop il y ai 2 cartes de même hauteur qu'une des 2 hauteurs. Dans les 2 cas il faut la seule carte de même hauteur que les 3 cartes déjà en jeu. Ce qui nous donne <strong>1/47 ≈ 0.0213</strong> soit environs <strong>2.1%</strong>.
#
# > Pour la straight flush, il qu'au preflop, le joueur ai 2 cartes de même couleur et qui se suivent et que flop il y ai 2 cartes de même couleur et qui forment une suite de 4 avec les cartes du joueur. Il faut donc une carte de même couleur et qui forme une suite de 5. Ce qui nous donne <strong>1/47 ≈ 0.0213<strong> soit envrions <strong>2.1%</strong>
#
# > Pour la straight flush royal, le pourcentage est le même que celui de la straight flush car seul le pourcentage d'avoir une suite 10, J, D, K, A change est plus rare mais ici nous calculons le poucentage d'avoir tel ou tel mains sans prendre en compte le poucentage d'avoir tel ou tel configurations de base ! Le pourcentage d'avoir une straight flush royale est donc d'environs <strong>2.1%</strong>.

# %% [markdown]
# # 4) OUTS
#
# ---
#
# *Les out sont en fait l'ensemble des cartes qui, si elles étaient dévoilées, pourrait permettre à un joueur d'avoir une meilleure main que celle qu'il a actuellement. Ce calcul est utilisé par tous les joueurs expérimenté pour savoir combien ils ont de chance de gagner (il en existe d'autre à combiné avec celui-là, mais ce calcul est primordiale.). Pour compter les outs, il faut compter le nombre de cartes qui nous feraient avoir une meilleure main. Par exemple, au preflop un joueur reçois 7♦ et 8♣ et qu'au le flop est composé de 9♣, 4♦, et K♠. Nous pouvons voir qu'une straight est possible (en général, on cherche à avoir une straight, une flush, ou au moins un carré, un brelan, ou un full housse, on ne comptera pas les paires, et les doubles paires, car ces mains ne sont pas assez fortes pour avoir un impact sur nos décisions). Donc pour avoir une straight il faut qu'un 5 et un 6 tombe à la turn et à la river. Étant donné qu'aucune de ces cartes n'a été encore dévoilé, on suppose qu'il y a les 4 cartes de 5, et les 4 cartes de 6 ce qui fait en tout 8 cartes et donc 8 outs.*
# <br><br>
#
# Afin de calculer notre probabilité d'avoir un out, ils nous faut deux données : la phase de jeu dans laquelle ont se trouve et les cartes déja en main.
#
# Par exemple dans le cas d'un flop, nous avons deux cartes en mains et disons que nous avons 8 possibilitées d'out. Afin de calculer la probabilité d'avoir un out nous devons prendre en compte le fait que nous possédons déja 2 cartes et que le flop est composé de 3 cartes, nous allons donc soustraire ces 5 cartes en tout au paquet de 52 cartes, ce qui nous fait 47.
# Ce qui nous permet d'avoir le calcul suivant <strong>8/47 = 0,1702</strong> nous avons donc environ <strong>17%</strong> de chance d'avoir un out dans le cas présent.
#
# Dans le cas de la river, il faut prendre en compte que le turn nous enleve une carte de plus par rapport au flop ce qui nous ramène à 46 cartes, en partant du principe que nous avons encore 8 out possible on fait le calcul suivant : <strong>8/46 = 0,1739</strong> soit environ <strong>17,4%</strong>.
#
# Le dernier cas étudié, est le calcul du pourcentage de chance de toucher à la turn ET à la river, nous devons donc faire : probabilité à la turn + probabilités à la river - ( la probabilité à la turn * probabilités à la river ) ce qui nous fait <strong>8/47 + 8/46 - ( 8/47 * 8/46 ) = 0,3145</strong> soit à peu pret <strong>31,5%</strong>.
#
# Comme nous pouvons le voir la formule est donc, le nombre de cartes en main que l'on notera "m", le nombre de cartes dans le paquet noté "p" et le nombre d'out possibles notés "o".
# Ce qui nous donne P(out) = o/(p-m).
